# %%
import numpy as np 
import pandas as pd

# %%
movies = pd.read_csv('BollywoodMovieDetail.csv')
ratings = pd.read_csv('BollywoodActorRanking.csv')

# %%
ratings.head()
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
movies.shape
# Out:
# (1284, 10)

# %%
for i in range(len(movies)):
    try:
        movies["mainActor"].concat(movies["actors"][i].split("|")[0].strip())
    except:
        continue

# %%
movies.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movies.loc[(movies["releaseYear"]==2011) & (movies["genre"] == "Action | Comedy | Drama")]
# Out:
#         imdbId                     title  releaseYear  releaseDate  \
# 832  tt1630282  Sahi Dhandhe Galat Bande         2011  19 Aug 2011
# 880  tt1773109       Yamla Pagla Deewana         2011  14 Jan 2011
#
#                        genre                                  writers  \
# 832  Action | Comedy | Drama                             Parvin Dabas
# 880  Action | Comedy | Drama  Jasvinder Bath (story) | Jasvinder Bath
#
#                                                 actors     directors  sequel  \
# 832  Anupam Kher | Sharat Saxena | Parvin Dabas | V...  Parvin Dabas     0.0
# 880  Nafisa Ali | Madhuri Bhattacharya | Emma Brown...  Samir Karnik     0.0
#
#      hitFlop
# 832        1
# 880        6

# %%
movies.head(10)# to get the first 10 rows
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 5  tt0238936                             Devdas         2002  12 Jul 2002
# 6  tt0247911        Aap Mujhe Achche Lagne Lage         2002  19 Apr 2002
# 7  tt0248126        Kabhi Khushi Kabhie Gham...         2001  14 Dec 2001
# 8  tt0248216                Na Tum Jaano Na Hum         2002  10 May 2002
# 9  tt0248617                         Yaadein...         2001  27 Jun 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# ...

# %%
movies.tail()# to get last 5 rows
# Out:
#          imdbId                 title  releaseYear  releaseDate     genre  \
# 1279  tt4121522  Shuruaat Ka Interval         2014  15 Aug 2014       NaN
# 1280  tt4187650      Trip to Bhangarh         2014  28 Aug 2014    Horror
# 1281  tt4190220              Zed Plus         2014  28 Nov 2014       NaN
# 1282  tt4219300       Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746                   Zid         2014  28 Nov 2014  Thriller
#
#                                                 writers  \
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                                NaN
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                                NaN
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# ...

# %%
movies.shape #to get the total no. of rows and columns
# Out:
# (1284, 10)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1231 non-null   object
#  4   genre        1282 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1281 non-null   object
#  7   directors    1280 non-null   object
#  8   sequel       1281 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
movies.describe(include="all")
# Out:
#            imdbId   title  releaseYear  releaseDate  genre       writers  \
# count        1284    1284  1284.000000         1231   1282          1165
# unique       1284    1284          NaN          710    215          1109
# top     tt0118578  Albela          NaN  02 Nov 2012  Drama  Dilip Shukla
# freq            1       1          NaN            6    113             6
# mean          NaN     NaN  2007.989097          NaN    NaN           NaN
# std           NaN     NaN     4.005243          NaN    NaN           NaN
# min           NaN     NaN  2001.000000          NaN    NaN           NaN
# 25%           NaN     NaN  2004.000000          NaN    NaN           NaN
# 50%           NaN     NaN  2008.000000          NaN    NaN           NaN
# 75%           NaN     NaN  2011.000000          NaN    NaN           NaN
# max           NaN     NaN  2014.000000          NaN    NaN           NaN
#
#                                                    actors     directors  \
# ...

# %%
movies.dtypes # to get the datatypes of all the columns
# Out:
# imdbId          object
# title           object
# releaseYear      int64
# releaseDate     object
# genre           object
# writers         object
# actors          object
# directors       object
# sequel         float64
# hitFlop          int64
# dtype: object

# %%
movies.isnull().sum() # to get the number of missing values in each column
# Out:
# imdbId           0
# title            0
# releaseYear      0
# releaseDate     53
# genre            2
# writers        119
# actors           3
# directors        4
# sequel           3
# hitFlop          0
# dtype: int64

# %%
movies.duplicated().sum() # to get the number of duplicated values
# Out:
# 0

# %%
movies.sample(10)# to get the random 10 rows from the dataset
# Out:
#          imdbId                    title  releaseYear  releaseDate  \
# 915   tt1886663      Satrangee Parachute         2011  25 Feb 2011
# 433   tt0485522               Umrao Jaan         2006  03 Nov 2006
# 5     tt0238936                   Devdas         2002  12 Jul 2002
# 1014  tt2155776      Yeh Jo Mohabbat Hai         2012  03 Aug 2012
# 860   tt1720254                Thank You         2011  08 Apr 2011
# 408   tt0475645  Vaah! Life Ho Toh Aisi!         2005  23 Dec 2005
# 399   tt0470398                    Kasak         2005  22 Jul 2005
# 664   tt1241195                    Aamir         2008  06 Jun 2008
# 1225  tt3359290             Bobby Jasoos         2014  04 Jul 2014
# 791   tt1570417    Accident on Hill Road         2010  31 Dec 2009
#
#                           genre  \
# 915     Comedy | Drama | Family
# 433             Drama | Romance
# 5             Musical | Romance
# 1014                      Drama
# 860    Comedy | Drama | Romance
# ...

# %%
movies = movies.drop(['writers'],axis=1)

# %%
ratings.head(10)
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
# 5      378    Hrithik Roshan          16       1120              5.89130
# 6      379   Priyanka Chopra          36       1990              4.45109
# 7      380    Kareena Kapoor          37       2200              4.86016
# 8      381     Ranbir Kapoor          11        890              6.95850
# 9      382             Kajol           6        450              6.38043
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# ...

# %%
ratings.tail(5)
# Out:
#      actorId        actorName  movieCount  ratingSum  normalizedMovieRank  \
# 296      669      Achint Kaur           4         80                  1.0
# 297      670  Yuvika Chaudhry           5        100                  1.0
# 298      671     Pankaj Berry           5        100                  1.0
# 299      672     Varun Dhawan           0          0                  NaN
# 300      673    Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 296           0                   NaN              1.00
# 297           0                   NaN              1.00
# 298           0                   NaN              1.00
# 299           0                   NaN              4.74
# 300           0                   NaN              4.80

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB
